# %%
import numpy as np
import matplotlib.pyplot as plt
from autokiddobot import

# %%
file=open(r"C:\Users\Mobin Ahmed\Downloads\FYP\FYP\kk.txt","r")

# %%
a1=file.readline()
f1=a1.split(',')
x=[]
for i in range(len(f1)):
    x.append(int(f1[i]))
a2=file.readline()
f2=a2.split(',')
y=[]
for i in range(len(f2)):
    y.append(int(f2[i]))
    
print(len(x))
print(len(y))
plt.scatter(x,y)
# Out:
# 306
# 306
